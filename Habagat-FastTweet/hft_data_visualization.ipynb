# %%
import pandas as pd
import numpy as np
from data_cleaner import *
from data_analysis import *
download_necessary_functions()

# %%
data = pd.read_csv('dataset\\DisasterPHClassification.csv')
data['Tokens'] = data['Text'].apply(lambda x: clean_text(x))

# %%
create_word_cloud(data)

# %%
data = pd.read_csv('dataset\\FastTweet.csv')
data['Tokens'] = data['Text'].apply(lambda x: clean_text(x))
MostFrequentWords(data, 50)

# %%
# PRE-TRAINED FASTTEXT
# Load Polyglot FastText embeddings
from data_vectorizer import *

model = LoadFastTweet('pretrained_gensim\\Habagat_FastTweetGS300.model')

# Convert tokens to Vectors and split for training and testing
X = GetFastTextVectorValues(model, data)
data['Disaster'] = 1
# Out:
# c:\Users\nicoo\OneDrive\Documents\Debug Files\NLP\Project\Disaster Related Tweets\data_vectorizer.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array([np.array([model.wv[i] for i in ls if i in words])

# %%
pcadf = PCATransform(data['Disaster'], X, 2)
KMeanTransform(data['Disaster'], pcadf, 5)

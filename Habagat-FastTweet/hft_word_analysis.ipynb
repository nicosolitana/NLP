# %%
import pandas as pd
from data_vectorizer import *
from data_visualize import *

# %%
# To Load pretrained fastText model 
ft_model = LoadFastTweetModel('pretrained_ft_us\\Habagat_FastTweet300.bin')
visualize_similarity(ft_model, 'hagupit', 20)
# Out:
#              x           y            word
# 0    45.410511 -191.840912       hagupitin
# 1   100.831924 -102.043343       hahagupit
# 2   191.670486 -160.984726       hagupit's
# 3    98.380890 -160.295471       hinagupit
# 4   149.128601 -128.878815     hinahagupit
# 5    50.650864 -132.737808         pagupit
# 6   183.752945 -218.924316     humahagupit
# 7    90.424278 -217.093155      paghagupit
# 8   139.639938 -187.379715  typhoonhagupit
# 9   133.200089 -247.550934       humagupit
# 10    2.193979  168.659500          haging
# 11  -73.180733  314.515808          nalang
# 12 -124.944984  296.588379          nating
# 13 -139.901550  156.298096         hunting
# 14 -103.901199  201.633896           nayan
# 15  -58.486458   25.609142       maaaaring
# 16  -86.629349  146.742889          eating
# 17  -26.571423   73.836609       reposting
# 18   22.185356  102.186302         hosting
# 19  -78.960327  248.621719         banging

# %%
# To Load pretrained fastText model 
ft_model = LoadFastTweetModel('base\\cc.tl.300.bin')
visualize_similarity(ft_model, 'hagupit', 20)
# Out:
#              x           y          word
# 0     9.927595 -189.841400     hahagupit
# 1    62.964848 -142.990723   hinahagupit
# 2   170.362595  -11.220817    paghagupit
# 3  -133.979263 -273.566071     hagupitin
# 4    79.974617 -215.526001   humahagupit
# 5   -79.640526  -72.154343  paghahagupit
# 6    74.996704  -71.539253     nahagupit
# 7  -180.249084  166.998016       Hagupit
# 8   151.537537 -205.104736     mahagupit
# 9    97.144302  121.292877     hinagupit
# 10   10.831099  -98.385056    naghagupit
# 11  -31.086168 -131.312881    maghagupit
# 12  144.477921 -113.541084    ipahagupit
# 13 -147.255905  -99.921791   panghagupit
# 14   46.735603 -299.150238     humagupit
# 15 -121.548851  113.420799       Jagupit
# 16   47.013432  -18.807060  ipinahagupit
# 17  -13.545129  -33.173214  inihahagupit
# 18  -66.851013 -224.149704   hahagupitin
# 19  -80.073257  157.826889     Humagupit

# %%
# To Load pretrained fastText supervised model 
ft_model = LoadFastTweet('pretrained_gensim\\Habagat_FastTweetGS300.model')
visualize_similarity(ft_model, 'hagupit', 20)
# Out:
#              x           y              word
# 0   -65.350830  106.718391        hagupit-it
# 1  -177.218460  208.669754         hagupit--
# 2  -226.866501   76.871140          hagupit-
# 3  -371.698853  153.091736            hagupi
# 4  -161.676041  524.762817         hagupitph
# 5  -174.687973  360.887848       hagupithits
# 6   -23.934347  271.589325       hagupit-hit
# 7   354.049744 -221.461929             gupit
# 8   102.349129   16.809757         hagupitin
# 9  -510.706390  225.759949             hagup
# 10  -13.962574  445.396790         hagupit's
# 11  155.382202  162.543533           hagupin
# 12 -358.034149  370.925323           hagupot
# 13  142.495132 -228.837326         hahagupit
# 14  214.713760 -374.922943         nahagupit
# 15 -348.081299  559.110657  hagupitrubyflood
# 16 -353.503479  -99.625137        hagupitang
# 17  430.298584 -499.938354       pag-hagupit
# 18  188.158157  419.001190           hagupet
# 19 -120.773354 -133.532837       manghagupit

# %%
# Specify input for analogy here
firstWord = 'tubig'
secondWord = 'hangin'
thirdWord = 'baha'

# %%
# Analogy using FastText Pre-Trained Unsupervised Model
ft_model = LoadFastTweetModel('pretrained_ft_us\\Habagat_FastTweet300.bin')
visualize_analogy(ft_model, firstWord, secondWord, thirdWord, 20)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.004s...
# [t-SNE] Computed neighbors for 20 samples in 0.033s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.240643
# [t-SNE] KL divergence after 1000 iterations: 0.405096
#              words          x           y
# 0          hangina  15.711405   28.467943
# 1          hanging -24.015423   -1.812173
# 2             hang -25.198799   36.333599
# 3         hahangin  88.163368  -31.114204
# 4          hanggan  59.618896   41.681366
# 5      bahagharing  99.061356   62.706619
# 6           mabaha -64.399620  -26.418684
# 7         mahangin  13.680802  -13.283425
# 8      kinakabahan  18.279268  113.313156
# 9          bagalan  46.118584  -41.401798
# 10         bahaing -69.059792   20.187855
# 11          bahang  31.196667   68.292969
# ...

# %%
# Analogy using FastText Pre-Trained Supervised Model
ft_model = LoadFastTweet('pretrained_gensim\\Habagat_FastTweetGS300.model')
visualize_analogy(ft_model, firstWord, secondWord, thirdWord, 20)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.000s...
# [t-SNE] Computed neighbors for 20 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.240643
# [t-SNE] KL divergence after 1000 iterations: 0.405096
#               words          x           y
# 0           hanginn  15.711405   28.467943
# 1          hanginng -24.015423   -1.812173
# 2          hanginnn -25.198799   36.333599
# 3           hangins  88.163368  -31.114204
# 4           hangin-  59.618896   41.681366
# 5           hangint  99.061356   62.706619
# 6          hahangin -64.399620  -26.418684
# 7          nahangin  13.680802  -13.283425
# 8           mhangin  18.279268  113.313156
# 9           hangini  46.118584  -41.401798
# 10         nghangin -69.059792   20.187855
# 11        hanginnnn  31.196667   68.292969
# ...

# %%
# Analogy using FastText Pre-Trained Base Model
ft_model = LoadFastTweetModel('base\\cc.tl.300.bin')
visualize_analogy(ft_model, firstWord, secondWord, thirdWord, 20)
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.001s...
# [t-SNE] Computed neighbors for 20 samples in 0.019s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.240643
# [t-SNE] KL divergence after 1000 iterations: 0.405096
#         words          x           y
# 0       bagyo  15.711405   28.467943
# 1     habagat -24.015423   -1.812173
# 2     hangin. -25.198799   36.333599
# 3       hangi  88.163368  -31.114204
# 4    hanginAt  59.618896   41.681366
# 5      umihip  99.061356   62.706619
# 6    hanginSa -64.399620  -26.418684
# 7      uuulan  13.680802  -13.283425
# 8        ulan  18.279268  113.313156
# 9   hanginKay  46.118584  -41.401798
# 10     bahang -69.059792   20.187855
# 11   pag-baha  31.196667   68.292969
# 12    pagbaha  14.077535  -70.296753
# 13  sandstorm  51.455502    2.864754
# ...
